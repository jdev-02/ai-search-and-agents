# %% [markdown]
# # CS3310 Lab 3
# ## Heuristic search
#
# Formulate the maze problem below into a search problem. The starting point of the maze is indicated by the red square, and the end goal is to reach the green square. my_maze.xlsx contains the boolean map of the maze where walls are denoted as '1' and channels are denoted as '0'.
#
# ![maze.PNG](attachment:maze.PNG)

# %% [markdown]
# ### 1. Formulate a problem solving agent
#
# Formalize the problem by defining the states, initial state, actions, transition model, goal test, and action cost.
#
# b. In my_search.py (use your copy form lab 2) create a new class called 'MazeProblem_Lab3'. MazeProblem_Lab3 should inherit from the 'Problem' class. Implement the following member functions in the MazeProblem_Lab3 class:
# - __init__(): initialize the initial state and goal state.
# - actions(params: state): Return the actions that can be executed from a given state.
# - result(params: state, action ): Return the state that results from executing the given action in the given state.
# - goal_test(params: state): Return True if the state is a goal.

# %% [markdown]
# ### 2. Heuristics
#
# Design two heuristics of your choice for this problem. Describe your heuristics below and implement them in my_search.py.
#
# a. h1 description: Manhattan distance = |delta x| + |delta y|
#
# b. h2 description: Euclidean distance = sqrt(x^2+y^2)

# %% [markdown]
# ### 3. Greedy Search
#
# Implement greedy_search( ) in my_search.py. Using your implentation, perform greedy search on the maze problem with your h1 and h2 heuristics separately. For each heuristic, print the number of nodes that get generated. The code below should execute a search and print the solution.

# %% [markdown]
# ### a. Greedy Search with h1

# %%
from my_search_LT_Goohs import *
maze = MazeProblem_Lab3() #instantiate maze problem
goal_state, nodes_generated = greedy_search_manhattan(maze) # search and return goal state
print(goal_state.solution()) # print solution
print(f"Nodes generated: {nodes_generated}")
print(goal_state) # print goal state
print(f"path cost: {goal_state.path_cost}")
# Out:
# ['Up', 'Right', 'Right', 'Right', 'Right', 'Right', 'Right', 'Right', 'Right', 'Right', 'Right', 'Up', 'Up', 'Up', 'Up', 'Left', 'Up', 'Up', 'Up', 'Up', 'Right', 'Right', 'Right', 'Right', 'Up', 'Up', 'Left', 'Left', 'Left', 'Up', 'Left', 'Left', 'Up', 'Up', 'Right', 'Right', 'Right', 'Right', 'Right', 'Right']
# Nodes generated: 95
# <Node (1, 16)>
# path cost: 40
# c:\Users\jgooh\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\internals\managers.py:1753: RuntimeWarning: invalid value encountered in cast
#   result[rl.indexer] = arr

# %% [markdown]
# ### b. Greedy Search with h2

# %%
from my_search_LT_Goohs import *
maze = MazeProblem_Lab3() #instantiate maze problem
goal_state, nodes_generated = greedy_search_euclidean(maze) # search and return goal state
print(goal_state.solution()) # print solution
print(f"Nodes generated: {nodes_generated}")
print(goal_state) # print goal state
print(f"path cost: {goal_state.path_cost}")
# Out:
# ['Up', 'Right', 'Right', 'Right', 'Right', 'Right', 'Right', 'Right', 'Right', 'Right', 'Right', 'Up', 'Up', 'Up', 'Up', 'Left', 'Up', 'Up', 'Up', 'Up', 'Right', 'Right', 'Right', 'Right', 'Up', 'Up', 'Left', 'Left', 'Left', 'Up', 'Left', 'Left', 'Up', 'Up', 'Right', 'Right', 'Right', 'Right', 'Right', 'Right']
# Nodes generated: 99
# <Node (1, 16)>
# path cost: 40
# c:\Users\jgooh\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\internals\managers.py:1753: RuntimeWarning: invalid value encountered in cast
#   result[rl.indexer] = arr

# %% [markdown]
# ### 4. A* Search
#
# Implement Astar_search( ) in my_search.py. Using your implentation, perform A* search on the maze problem with your h1 and h2 heuristics separately. For each heuristic, print the number of nodes that get generated. The code below should execute a search and print the solution.

# %% [markdown]
# ### a. A* Search with h1

# %%
from my_search_LT_Goohs import *
maze = MazeProblem_Lab3() #instantiate maze problem
goal_state, nodes_generated = astar_search_manhattan(maze) # search and return goal state
print(goal_state.solution()) # print solution
print(f"Nodes generated: {nodes_generated}")
print(goal_state) # print goal state
print(f"path cost: {goal_state.path_cost}")
# Out:
# ['Up', 'Right', 'Right', 'Right', 'Right', 'Right', 'Right', 'Right', 'Right', 'Right', 'Right', 'Up', 'Up', 'Up', 'Up', 'Left', 'Up', 'Up', 'Up', 'Up', 'Left', 'Left', 'Left', 'Up', 'Up', 'Up', 'Up', 'Up', 'Right', 'Right', 'Right', 'Right', 'Right', 'Right', 'Right', 'Right']
# Nodes generated: 158
# <Node (1, 16)>
# path cost: 36
# c:\Users\jgooh\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\internals\managers.py:1753: RuntimeWarning: invalid value encountered in cast
#   result[rl.indexer] = arr

# %% [markdown]
# ### b. A* Search with h2

# %%
from my_search_LT_Goohs import *
maze = MazeProblem_Lab3() #instantiate maze problem
goal_state, nodes_generated = astar_search_euclidean(maze) # search and return goal state
print(goal_state.solution()) # print solution
print(f"Nodes generated: {nodes_generated}")
print(goal_state) # print goal state
print(f"path cost: {goal_state.path_cost}")
# Out:
# ['Up', 'Right', 'Right', 'Right', 'Right', 'Right', 'Right', 'Right', 'Right', 'Right', 'Right', 'Up', 'Up', 'Up', 'Up', 'Left', 'Up', 'Up', 'Up', 'Up', 'Left', 'Left', 'Left', 'Up', 'Up', 'Right', 'Right', 'Up', 'Up', 'Up', 'Right', 'Right', 'Right', 'Right', 'Right', 'Right']
# Nodes generated: 168
# <Node (1, 16)>
# path cost: 36
# c:\Users\jgooh\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\internals\managers.py:1753: RuntimeWarning: invalid value encountered in cast
#   result[rl.indexer] = arr

# %% [markdown]
# ### 5. Results
#
# Please fill in the table with your results. Please compare each algorithm and discuss which performed best under which heuristic.

# %% [markdown]
# <table style="width:100%">
#   <tr>
#     <th></th>
#     <th>Greedy h1</th>
#     <th>Greedy h2</th>
#     <th>Astar h1</th>
#     <th>Astar h2</th>
#   </tr>
#   <tr>
#     <td>Nodes Generated</td>
#     <td>95</td>
#     <td>99</td>
#     <td>158</td>
#     <td>168</td>
#   </tr>
#   <tr>
#     <td>Returned Path Cost</td>
#     <td>40</td>
#     <td>40</td>
#     <td>36</td>
#     <td>36</td>
#   </tr>
# </table>

# %% [markdown]
# ## discussion
#
# On this 4-connected, unit-cost maze, Manhattan is the more informative heuristic than Euclidean, so it consistently generated fewer nodes for both Greedy and A*. Comparing algorithms, A* returned the optimal path cost with both heuristics, as expected with admissible/consistent h. Greedy Best-First prioritized low-h states but ignored g-cost, so it sometimes took longer detours and produced a higher path cost. The most efficient and effective combination was A* + Manhattan, which achieved the lowest node expansions among optimal solvers and the optimal path.
